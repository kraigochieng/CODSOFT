# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
sns.set_theme(style="whitegrid")

# %%
credit_card_df = pd.read_csv("creditcard.csv")

# %%
credit_card_df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
# # Convert time column to numeric in order to convert it to datetime
# credit_card_df["Time"] = pd.to_numeric(credit_card_df["Time"])
# # I set origin time to 1st day of September 2013 since that is the details of the Kaggle Dataset
# credit_card_df["Time"] = pd.to_datetime(credit_card_df["Time"], unit="s", origin="2013-09-01")
# credit_card_df["Time"].dtype

# %%
# credit_card_df["Day"] = credit_card_df["Time"].dt.day
# credit_card_df["Hour"] = credit_card_df["Time"].dt.hour
# credit_card_df["Minute"] = (credit_card_df["Hour"] * 60) +  credit_card_df["Time"].dt.minute
# credit_card_df["Second"] = (credit_card_df["Minute"] * 60) +  credit_card_df["Time"].dt.second

# %%
credit_card_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# sns.lineplot(x=credit_card_df["Time"], y=credit_card_df["Amount"], hue=credit_card_df["Class"])
# sns.lineplot(x=credit_card_df["Minute"], y=credit_card_df["Class"])

# %%
# aggregates = ["mean", "median", "min"]

# credit_card_time_eda_df = credit_card_df.groupby(["Hour"], as_index=False)[["Amount"]].agg(aggregates).reset_index()
# print(credit_card_time_eda_df)
# for aggregate in aggregates:
#     sns.lineplot(x=credit_card_time_eda_df["Hour"], y=credit_card_time_eda_df["Amount"][aggregate], label=aggregate, marker="o")
# plt.title("Mean and Median Amounts Per Hour")
# plt.show()

# credit_card_max_amount_df = credit_card_df.groupby(["Hour"], as_index=False)[["Amount"]].max()
# # print(credit_card_max_amount_df)
# sns.lineplot(x=credit_card_max_amount_df["Hour"], y=credit_card_max_amount_df["Amount"], marker="o")
# plt.title("Max Amounts Per Hour")
# plt.show()

# %%
# CHeck if there is any row without a class
credit_card_df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Know the proportions of the feature class
credit_card_df["Class"].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %% [markdown]
# ##### The amounts are really small amounts throughout the data set. Downsampling shall be done.

# %%
true_df = credit_card_df[credit_card_df["Class"] == 0]
fraud_df = credit_card_df[credit_card_df["Class"] == 1]

print(true_df.shape, fraud_df.shape)
# Out:
# (284315, 31) (492, 31)

# %%
true_sample_df = true_df.sample(n=fraud_df.shape[0])
true_sample_df.shape
# Out:
# (492, 31)

# %%
sample_credit_card_df = pd.concat([true_sample_df, fraud_df])
sample_credit_card_df.shape
# Out:
# (984, 31)

# %%
# # Plot Amount Per day
# time_bins = ["Day", "Hour"]
# for time_bin in time_bins:
#     time_bin_values = list(sample_credit_card_df[time_bin].unique())
#     time_bin_values.sort()
#     for time_bin_value in time_bin_values:
#         print(time_bin, time_bin_value)
#         credit_card_by_time_bin = sample_credit_card_df[sample_credit_card_df[time_bin] == time_bin_value]
#         sns.lineplot(x=credit_card_by_time_bin["Minute"], y=credit_card_by_time_bin["Amount"], hue=credit_card_by_time_bin["Class"])
#         plt.show()

# %%
# Time series data before downsampling
# sns.lineplot(x=sample_credit_card_df["Time"], y=sample_credit_card_df["Amount"])

# %%
# columns_to_exclude = ["Class", "Time", "Day", "Hour", "Minute", "Second"]
columns_to_exclude = ["Class", "Time"]
for column in sample_credit_card_df.drop(columns=columns_to_exclude, axis=1, inplace=False).columns:
    print("Column:",column)
    sns.violinplot(x=sample_credit_card_df["Class"], y=sample_credit_card_df[column], inner="quartile", hue=sample_credit_card_df["Class"])
    plt.show()
# Out:
# Column: V1
# Column: V2
# Column: V3
# Column: V4
# Column: V5
# Column: V6
# Column: V7
# Column: V8
# Column: V9
# Column: V10
# Column: V11
# Column: V12
# Column: V13
# Column: V14
# Column: V15
# Column: V16
# Column: V17
# Column: V18
# Column: V19
# Column: V20
# Column: V21
# Column: V22
# Column: V23
# Column: V24
# Column: V25
# Column: V26
# Column: V27
# Column: V28
# Column: Amount

# %%
# Splitting training and testing data for feature selection
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, mutual_info_classif, RFE
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier

credit_card_df_fs = sample_credit_card_df.copy()

X_fs = credit_card_df_fs.drop(["Time","Class"], axis=1, inplace=False)
y_fs = credit_card_df_fs["Class"]

X_train_fs, X_test_fs, y_train_fs, y_test_fs = train_test_split(X_fs, y_fs, test_size=0.7, shuffle=True, stratify=y_fs ,random_state=1)

k_best_f1_scores = []
k_best_best_features = []
rfe_f1_scores = []
rfe_best_features = []

k_best_rf = RandomForestClassifier(random_state=1)
rfe_rf = RandomForestClassifier(random_state=1)
rf = RandomForestClassifier(random_state=1)

divider = 2 # Features are too many, i shall loop only half
k_limit = 10
for k in range(1, k_limit):
    # Creating feature selectors
    k_best_selector = SelectKBest(score_func=mutual_info_classif, k=k)
    k_best_selector.fit(X_train_fs, y_train_fs)

    rfe_selector = RFE(estimator=rfe_rf, n_features_to_select=k, step=1)
    rfe_selector.fit(X_train_fs, y_train_fs)

    # Feature masks
    k_best_feature_mask = k_best_selector.get_support()
    rfe_feature_mask = rfe_selector.get_support()

    # Apply feature selectors to data sets
    k_best_selected = {
        "X_train": k_best_selector.transform(X_train_fs),
        "X_test": k_best_selector.transform(X_test_fs)
    }

    rfe_selected = {
        "X_train": rfe_selector.transform(X_train_fs),
        "X_test": rfe_selector.transform(X_test_fs)
    }
    
    # Training models
    k_best_rf.fit(k_best_selected["X_train"], y_train_fs)
    rfe_rf.fit(rfe_selected["X_train"], y_train_fs)

   
    # Obtaining scores
    k_best_y_pred_fs = k_best_rf.predict(k_best_selected["X_test"])
    rfe_y_pred = rfe_rf.predict(rfe_selected["X_test"])

    k_best_f1_scores.append(round(f1_score(y_test_fs, k_best_y_pred_fs), 3))
    rfe_f1_scores.append(round(f1_score(y_test_fs, rfe_y_pred), 3))
    
    current_k_best_best_features = X_train_fs.columns[k_best_feature_mask].to_list()
    current_rfe_best_features = X_train_fs.columns[rfe_feature_mask].to_list()
    
    k_best_best_features.append(current_k_best_best_features)
    rfe_best_features.append(current_rfe_best_features)
    
    # rf.fit(X_train_fs, y_train_fs)

    # print(rf.feature_importances_)

    print("K Value:", k)
    print("==================")
    print("K Best:", current_k_best_best_features)
    print("RFE:", current_rfe_best_features)
    print("")

f1_score_df = pd.DataFrame({
    "k": np.arange(1, k_limit),
    "k_best": k_best_f1_scores,
    "k_best_features": str(k_best_best_features),
    "rfe": rfe_f1_scores,
    "rfe_best_features": str(rfe_best_features)
})

f1_score_df
# Out:
# K Value: 1
# ...
# K Best: ['V14']
# RFE: ['V10']
#
# K Value: 2
# ...
# K Best: ['V10', 'V14']
# RFE: ['V4', 'V10']
#
# K Value: 3
# ...
# K Best: ['V10', 'V14', 'V17']
# RFE: ['V4', 'V10', 'V14']
#
# K Value: 4
# ...
# K Best: ['V10', 'V12', 'V14', 'V17']
# RFE: ['V4', 'V10', 'V12', 'V14']
#
# K Value: 5
# ...
# K Best: ['V4', 'V10', 'V12', 'V14', 'V17']
# RFE: ['V4', 'V10', 'V11', 'V12', 'V14']
#
# K Value: 6
# ...
# K Best: ['V4', 'V10', 'V11', 'V12', 'V14', 'V17']
# RFE: ['V4', 'V10', 'V11', 'V12', 'V14', 'V17']
#
# K Value: 7
# ...
# K Best: ['V3', 'V4', 'V10', 'V11', 'V12', 'V14', 'V17']
# RFE: ['V3', 'V4', 'V10', 'V11', 'V12', 'V14', 'V17']
#
# K Value: 8
# ...
# K Best: ['V3', 'V4', 'V7', 'V10', 'V11', 'V12', 'V14', 'V17']
# RFE: ['V3', 'V4', 'V7', 'V10', 'V11', 'V12', 'V14', 'V17']
#
# K Value: 9
# ...
# K Best: ['V3', 'V4', 'V7', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17']
# RFE: ['V3', 'V4', 'V7', 'V10', 'V11', 'V12', 'V14', 'V17', 'V19']
#    k  k_best                                    k_best_features    rfe  \
# ...

# %%
sns.lineplot(x=f1_score_df["k"], y=f1_score_df["k_best"], marker="o")
sns.lineplot(x=f1_score_df["k"], y=f1_score_df["rfe"], marker="o")
# Out:
# <Axes: xlabel='k', ylabel='k_best'>

# %%
import ast
# Selecting features dynamically
best_k = 6

row_select = f1_score_df["k"] == best_k

features_string = f1_score_df.loc[row_select]["k_best_features"].iloc[0]

features_list = ast.literal_eval(features_string)

relevant_columns = features_list[best_k - 1]

relevant_columns.append("Class")

final_sample_credit_card_df = credit_card_df[relevant_columns]

final_sample_credit_card_df
# Out:
#               V4       V10       V11       V12       V14       V17  Class
# 0       1.378155  0.090794 -0.551600 -0.617801 -0.311169  0.207971      0
# 1       0.448154 -0.166974  1.612727  1.065235 -0.143772 -0.114805      0
# 2       0.379780  0.207643  0.624501  0.066084 -0.165946  1.109969      0
# 3      -0.863291 -0.054952 -0.226487  0.178228 -0.287924 -0.684093      0
# 4       0.403034  0.753074 -0.822843  0.538196 -1.119670 -0.237033      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 284802 -2.066656  4.356170 -1.593105  2.711941  4.626942  1.991691      0
# 284803 -0.738589 -0.975926 -0.150189  0.915802 -0.675143 -0.025693      0
# 284804 -0.557828 -0.484782  0.411614  0.063119 -0.510602  0.313502      0
# 284805  0.689799 -0.399126 -1.933849 -0.962886  0.449624  0.509928      0
# 284806 -0.506271 -0.915427 -1.040458 -0.031513 -0.084316 -0.660377      0
#
# [284807 rows x 7 columns]

# %%
# credit_card_df.boxplot(column="Amount", by="Class")
# plt.show()
for column in final_sample_credit_card_df.drop(columns=["Class"], axis=1, inplace=False).columns:
    print("Column:", column)
    sns.boxplot(x="Class", y=column, data=final_sample_credit_card_df, hue="Class")
    plt.show()
# Out:
# Column: V4
# Column: V10
# Column: V11
# Column: V12
# Column: V14
# Column: V17

# %% [markdown]
# ##### The selected features really distinguish the classes. For each class, the distribution is different.

# %%
# Split Data
from sklearn.model_selection import train_test_split
X = final_sample_credit_card_df.drop(columns=["Class"], axis=1)
y = final_sample_credit_card_df["Class"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True,stratify=y, random_state=1)

# %%
# Hyperparameter finetuning
# This has been commented out since it is very time expensive

# from sklearn.model_selection import RandomizedSearchCV
# from scipy.stats import randint

# parameters =  {
#     'n_estimators': randint(50, 200),
#     'max_depth': randint(1, 20)
#     }

# random_search = RandomizedSearchCV(
#     rf,
#     param_distributions=parameters,
#     n_iter=10,
#     cv=5
# )

# random_search.fit(X_train, y_train)

# parameters = random_search.best_params_

# %%
# Final Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# rf = RandomForestClassifier(n_estimators=parameters["n_estimators"], max_depth=parameters["max_depth"], random_state=1)
rf = RandomForestClassifier(random_state=1)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
print("Accuracy:",accuracy_score(y_true=y_test, y_pred=y_pred))
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
# Accuracy: 0.9996371850239341
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.95      0.84      0.89       148
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.92      0.94     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# #### Telling if something is not a fraud is easy.
#
# #### Identifying a fraud involves some luck.
